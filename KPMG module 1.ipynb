# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('kpmg.xlsx',sheet_name='Transactions')

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
# transaction_id             20000 non-null int64
# product_id                 20000 non-null int64
# customer_id                20000 non-null int64
# transaction_date           20000 non-null datetime64[ns]
# online_order               19640 non-null float64
# order_status               20000 non-null object
# brand                      19803 non-null object
# product_line               19803 non-null object
# product_class              19803 non-null object
# product_size               19803 non-null object
# list_price                 20000 non-null float64
# standard_cost              19803 non-null float64
# product_first_sold_date    19803 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df.product_first_sold_date =pd.to_datetime(df.product_first_sold_date)

# %%
df.tail()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
#       order_status          brand product_line product_class product_size  \
# 19995     Approved     OHM Cycles     Standard          high       medium
# 19996     Approved          Solex         Road        medium       medium
# 19997     Approved     OHM Cycles     Standard        medium       medium
# 19998     Approved     OHM Cycles     Standard          high       medium
# 19999     Approved  Trek Bicycles     Standard        medium        small
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
# transaction_id             20000 non-null int64
# product_id                 20000 non-null int64
# customer_id                20000 non-null int64
# transaction_date           20000 non-null datetime64[ns]
# online_order               19640 non-null float64
# order_status               20000 non-null object
# brand                      19803 non-null object
# product_line               19803 non-null object
# product_class              19803 non-null object
# product_size               19803 non-null object
# list_price                 20000 non-null float64
# standard_cost              19803 non-null float64
# product_first_sold_date    19803 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.order_status.value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
df['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
df['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
df['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
ef=pd.read_excel('kpmg.xlsx',sheet_name='NewCustomerList')

# %%
ef.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
ef.shape
# Out:
# (1000, 23)

# %%
ef.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
ef.job_title.value_counts()
# Out:
# Associate Professor             15
# Software Consultant             14
# Environmental Tech              14
# Chief Design Engineer           13
# VP Sales                        12
#                                 ..
# Accountant II                    1
# Database Administrator I         1
# Human Resources Assistant IV     1
# Systems Administrator III        1
# Software Test Engineer II        1
# Name: job_title, Length: 184, dtype: int64

# %%
ef.gender.value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
ef.wealth_segment.value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
ef.deceased_indicator.value_counts()
# Out:
# N    1000
# Name: deceased_indicator, dtype: int64

# %%
ef.country.value_counts()
# Out:
# Australia    1000
# Name: country, dtype: int64

# %%
cols = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20']
ef = ef.drop(cols, axis=1)

# %%
ef.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
ef.duplicated().sum()
# Out:
# 0

# %%
ef=ef.replace({'gender':'U'},'Unspecified')

# %%
ef.gender.value_counts()
# Out:
# Female         513
# Male           470
# Unspecified     17
# Name: gender, dtype: int64

# %%
hf=pd.read_excel('kpmg.xlsx',sheet_name='CustomerDemographic')

# %%
hf.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
hf.shape
# Out:
# (3999, 17)

# %%
hf.duplicated().any()
# Out:
# False

# %%
hf.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
hf.gender.value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# M            1
# Femal        1
# F            1
# Name: gender, dtype: int64

# %%
hf.replace({'gender':['F','Femal']},'Female',inplace=True)

# %%
hf.replace({'gender':'M'},'Male',inplace=True)

# %%
hf.replace({'gender':'U'},'Unspecified',inplace=True)

# %%
hf.gender.value_counts()
# Out:
# Female         2039
# Male           1873
# Unspecified      88
# Name: gender, dtype: int64

# %%
hf.wealth_segment.value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64

# %%
hf.deceased_indicator.value_counts()
# Out:
# N    3998
# Y       2
# Name: deceased_indicator, dtype: int64

# %%
hf.owns_car.value_counts()
# Out:
# Yes    2024
# No     1976
# Name: owns_car, dtype: int64

# %%
hf = hf.drop('default', axis='columns')

# %%
gf=pd.read_excel('kpmg.xlsx',sheet_name='CustomerAddress')

# %%
gf.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
gf.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
gf.duplicated().any()
# Out:
# False

# %%
df.shape#transactio
# Out:
# (20000, 13)

# %%
ef.shape#newcustomer
# Out:
# (1000, 18)

# %%
hf.shape#customerdemo
# Out:
# (4000, 12)

# %%
gf.shape#customeradd
# Out:
# (3999, 6)

# %%
hf=pd.merge(hf,gf,how='right',on='customer_id')

# %%
hf.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            4          Talbot        NaN    Male
# 3            5  Sheila-kathryn     Calton  Female
# 4            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                 93.0 1953-10-12     Executive Secretary
# 1                                 81.0 1980-12-16  Administrative Officer
# 2                                 33.0 1961-10-03                     NaN
# 3                                 56.0 1977-05-13           Senior Editor
# 4                                 35.0 1966-09-16                     NaN
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
hf.shape
# Out:
# (3999, 17)

# %%
hf.tail()
# Out:
#       customer_id first_name last_name gender  \
# 3994         3999  Patrizius       NaN   Male
# 3995         4000      Kippy   Oldland   Male
# 3996         4001        NaN       NaN    NaN
# 3997         4002        NaN       NaN    NaN
# 3998         4003        NaN       NaN    NaN
#
#       past_3_years_bike_related_purchases        DOB             job_title  \
# 3994                                 11.0 1973-10-24                   NaN
# 3995                                 76.0 1991-11-05  Software Engineer IV
# 3996                                  NaN        NaT                   NaN
# 3997                                  NaN        NaT                   NaN
# 3998                                  NaN        NaT                   NaN
#
#      job_industry_category     wealth_segment deceased_indicator owns_car  \
# 3994         Manufacturing  Affluent Customer                  N      Yes
# 3995                   NaN  Affluent Customer                  N       No
# ...

# %%
hf=hf.drop(hf.index[-3:])

# %%
hf.tail()
# Out:
#       customer_id first_name last_name       gender  \
# 3991         3996    Rosalia  Halgarth       Female
# 3992         3997     Blanch    Nisuis       Female
# 3993         3998     Sarene   Woolley  Unspecified
# 3994         3999  Patrizius       NaN         Male
# 3995         4000      Kippy   Oldland         Male
#
#       past_3_years_bike_related_purchases        DOB              job_title  \
# 3991                                  8.0 1975-08-09  VP Product Management
# 3992                                 87.0 2001-07-13        Statistician II
# 3993                                 60.0        NaT      Assistant Manager
# 3994                                 11.0 1973-10-24                    NaN
# 3995                                 76.0 1991-11-05   Software Engineer IV
#
#      job_industry_category     wealth_segment deceased_indicator owns_car  \
# 3991                Health      Mass Customer                  N       No
# ...

# %%
ef['customer_id']=range(4001,4001+len(ef))

# %%
ef.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
ef.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value', 'customer_id'],
#       dtype='object')

# %%
col=['customer_id','first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
       'property_valuation', 'Rank', 'Value']
ef=ef.reindex(columns=col)

# %%
ef.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         4001    Chickie    Brister    Male
# 1         4002      Morly     Genery    Male
# 2         4003    Ardelis  Forrester  Female
# 3         4004     Lucine      Stutt  Female
# 4         4005    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# ...

# %%
ef.shape
# Out:
# (1000, 19)

# %%
hf.shape
# Out:
# (3996, 17)

# %%
final=pd.concat([hf,ef],ignore_index=True,sort=False)

# %%
final
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               4          Talbot        NaN    Male
# 3               5  Sheila-kathryn     Calton  Female
# 4               6            Curr  Duckhouse    Male
# ...           ...             ...        ...     ...
# 4991         4996       Ferdinand  Romanetti    Male
# 4992         4997            Burk    Wortley    Male
# 4993         4998        Melloney      Temby  Female
# 4994         4999          Dickie    Cubbini    Male
# 4995         5000           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                    93.0 1953-10-12
# 1                                    81.0 1980-12-16
# 2                                    33.0 1961-10-03
# 3                                    56.0 1977-05-13
# 4                                    35.0 1966-09-16
# ...

# %%
final.shape
# Out:
# (4996, 19)

# %%
final.isnull().sum()
# Out:
# customer_id                               0
# first_name                                0
# last_name                               154
# gender                                    0
# past_3_years_bike_related_purchases       0
# DOB                                     104
# job_title                               610
# job_industry_category                   820
# wealth_segment                            0
# deceased_indicator                        0
# owns_car                                  0
# tenure                                   87
# address                                   0
# postcode                                  0
# state                                     0
# country                                   0
# property_valuation                        0
# Rank                                   3996
# Value                                  3996
# dtype: int64

# %%
df.customer_id.value_counts().shape
# Out:
# (3494,)

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
final1=pd.merge(df,final,on='customer_id')

# %%
final1
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19963           19854          68          130       2017-02-02           1.0
# 19964           17966          17         2789       2017-12-06           0.0
# 19965           18462          80         2789       2017-06-20           0.0
# 19966           17981          69         3446       2017-12-26           1.0
# 19967           18165          86         3446       2017-12-03           0.0
#
# ...
